# %% [markdown]
# <a href="https://colab.research.google.com/github/mjmousavi97/Computer-Vision/blob/main/projects/pro-004/src/GoogleNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets, models
from torch.utils.data import DataLoader
import wandb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Transforms for training and validation
data_transform = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),

    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
wandb.init(
    project="Inception-5flowers", config={
        "learning_rate": 0.001,
        "epochs": 50,
        "batch_size": 16,
        "architecture": "InceptionV1",
        "pretrained": True,
        "input_size":224
    }
)

config = wandb.config
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  1
# wandb: You chose 'Create a W&B account'
# wandb: Create an account here: https://wandb.ai/authorize?signup=true&ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: mohammadjavad-mousavi97 (mohammadjavad-mousavi97-arak-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251221_120704-zzd1j3tu</code>
# Syncing run <strong><a href='https://wandb.ai/mohammadjavad-mousavi97-arak-university/Inception-5flowers/runs/zzd1j3tu' target="_blank">neat-night-1</a></strong> to <a href='https://wandb.ai/mohammadjavad-mousavi97-arak-university/Inception-5flowers' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mohammadjavad-mousavi97-arak-university/Inception-5flowers' target="_blank">https://wandb.ai/mohammadjavad-mousavi97-arak-university/Inception-5flowers</a>
#  View run at <a href='https://wandb.ai/mohammadjavad-mousavi97-arak-university/Inception-5flowers/runs/zzd1j3tu' target="_blank">https://wandb.ai/mohammadjavad-mousavi97-arak-university/Inception-5flowers/runs/zzd1j3tu</a>

# %%
train_dir = "/content/drive/MyDrive/Colab Notebooks/flowers/train"
val_dir = "/content/drive/MyDrive/Colab Notebooks/flowers/val"

train_dataset = datasets.ImageFolder(train_dir, transform=data_transform['train'])
val_dataset = datasets.ImageFolder(val_dir, transform=data_transform['val'])

train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config.batch_size, shuffle=False)

# %%
from torchvision.models import GoogLeNet_Weights

model = models.googlenet(weights=GoogLeNet_Weights.DEFAULT)
model.fc = nn.Linear(model.fc.in_features, 5)

for param in model.parameters():
    param.requires_grad = False

for param in model.fc.parameters():
    param.requires_grad = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

wandb.watch(model, log="all", log_freq=10)
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 129MB/s]

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)

# %%
def train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=10, log_every=10):
    device = next(model.parameters()).device

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for step, (images, labels) in enumerate(train_loader):
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            bs = labels.size(0)
            running_loss += loss.item() * bs
            preds = outputs.argmax(dim=1)
            correct += (preds == labels).sum().item()
            total += bs

            if (step + 1) % log_every == 0:
                train_loss_step = running_loss / max(1, total)
                train_acc_step = correct / max(1, total)
                wandb.log(
                    {
                        "epoch": epoch + 1,
                        "step": epoch * len(train_loader) + (step + 1),
                        "train/loss": train_loss_step,
                        "train/acc": train_acc_step,
                        "lr": optimizer.param_groups[0]["lr"],
                    }
                )

        train_loss = running_loss / max(1, total)
        train_acc = correct / max(1, total)

        model.eval()
        val_loss_sum = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device, non_blocking=True)
                labels = labels.to(device, non_blocking=True)

                outputs = model(images)
                loss = criterion(outputs, labels)

                bs = labels.size(0)
                val_loss_sum += loss.item() * bs
                preds = outputs.argmax(dim=1)
                val_correct += (preds == labels).sum().item()
                val_total += bs

        val_loss = val_loss_sum / max(1, val_total)
        val_acc = val_correct / max(1, val_total)

        wandb.log(
            {
                "epoch": epoch + 1,
                "train/loss_epoch": train_loss,
                "train/acc_epoch": train_acc,
                "val/loss": val_loss,
                "val/acc": val_acc,
            }
        )

        print(
            f"Epoch {epoch+1}/{num_epochs} | "
            f"train_loss={train_loss:.4f} train_acc={train_acc:.4f} | "
            f"val_loss={val_loss:.4f} val_acc={val_acc:.4f}"
        )

    print("Training complete!")

# %%
train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=config.epochs)
# Out:
# Epoch 1/50 | train_loss=0.9029 train_acc=0.7061 | val_loss=0.5588 val_acc=0.8259
# Epoch 2/50 | train_loss=0.5980 train_acc=0.7964 | val_loss=0.5009 val_acc=0.8309
# Epoch 3/50 | train_loss=0.5106 train_acc=0.8246 | val_loss=0.4528 val_acc=0.8556
# Epoch 4/50 | train_loss=0.4818 train_acc=0.8283 | val_loss=0.4413 val_acc=0.8566
# Epoch 5/50 | train_loss=0.4646 train_acc=0.8393 | val_loss=0.3882 val_acc=0.8754
# Epoch 6/50 | train_loss=0.4556 train_acc=0.8386 | val_loss=0.3859 val_acc=0.8675
# Epoch 7/50 | train_loss=0.4426 train_acc=0.8416 | val_loss=0.3728 val_acc=0.8783
# Epoch 8/50 | train_loss=0.4318 train_acc=0.8473 | val_loss=0.3816 val_acc=0.8734
# Epoch 9/50 | train_loss=0.4313 train_acc=0.8423 | val_loss=0.3732 val_acc=0.8714
# Epoch 10/50 | train_loss=0.4158 train_acc=0.8508 | val_loss=0.3618 val_acc=0.8704
# Epoch 11/50 | train_loss=0.4217 train_acc=0.8466 | val_loss=0.3586 val_acc=0.8813
# Epoch 12/50 | train_loss=0.4162 train_acc=0.8538 | val_loss=0.3627 val_acc=0.8724
# Epoch 13/50 | train_loss=0.4107 train_acc=0.8533 | val_loss=0.3504 val_acc=0.8803
# Epoch 14/50 | train_loss=0.4047 train_acc=0.8515 | val_loss=0.3725 val_acc=0.8714
# Epoch 15/50 | train_loss=0.4246 train_acc=0.8448 | val_loss=0.3581 val_acc=0.8823
# Epoch 16/50 | train_loss=0.4053 train_acc=0.8505 | val_loss=0.3696 val_acc=0.8684
# Epoch 17/50 | train_loss=0.4036 train_acc=0.8520 | val_loss=0.3605 val_acc=0.8684
# Epoch 18/50 | train_loss=0.3759 train_acc=0.8603 | val_loss=0.3416 val_acc=0.8853
# Epoch 19/50 | train_loss=0.3838 train_acc=0.8520 | val_loss=0.3556 val_acc=0.8724
# Epoch 20/50 | train_loss=0.3806 train_acc=0.8603 | val_loss=0.3583 val_acc=0.8783
# Epoch 21/50 | train_loss=0.3866 train_acc=0.8605 | val_loss=0.3501 val_acc=0.8793
# Epoch 22/50 | train_loss=0.3985 train_acc=0.8548 | val_loss=0.3470 val_acc=0.8813
# Epoch 23/50 | train_loss=0.3910 train_acc=0.8568 | val_loss=0.3740 val_acc=0.8764
# Epoch 24/50 | train_loss=0.3863 train_acc=0.8538 | val_loss=0.3490 val_acc=0.8793
# Epoch 25/50 | train_loss=0.3734 train_acc=0.8615 | val_loss=0.3534 val_acc=0.8803
# Epoch 26/50 | train_loss=0.4035 train_acc=0.8555 | val_loss=0.3431 val_acc=0.8823
# Epoch 27/50 | train_loss=0.3881 train_acc=0.8565 | val_loss=0.3600 val_acc=0.8714
# Epoch 28/50 | train_loss=0.3745 train_acc=0.8658 | val_loss=0.3502 val_acc=0.8843
# Epoch 29/50 | train_loss=0.3653 train_acc=0.8633 | val_loss=0.3411 val_acc=0.8813
# Epoch 30/50 | train_loss=0.3867 train_acc=0.8558 | val_loss=0.3522 val_acc=0.8833
# Epoch 31/50 | train_loss=0.3742 train_acc=0.8645 | val_loss=0.3583 val_acc=0.8655
# Epoch 32/50 | train_loss=0.3880 train_acc=0.8600 | val_loss=0.3355 val_acc=0.8863
# Epoch 33/50 | train_loss=0.3823 train_acc=0.8573 | val_loss=0.3440 val_acc=0.8803
# Epoch 34/50 | train_loss=0.3812 train_acc=0.8590 | val_loss=0.3530 val_acc=0.8714
# Epoch 35/50 | train_loss=0.3890 train_acc=0.8498 | val_loss=0.3700 val_acc=0.8813
# Epoch 36/50 | train_loss=0.3805 train_acc=0.8628 | val_loss=0.3419 val_acc=0.8724
# Epoch 37/50 | train_loss=0.3813 train_acc=0.8538 | val_loss=0.3352 val_acc=0.8764
# Epoch 38/50 | train_loss=0.3933 train_acc=0.8528 | val_loss=0.3646 val_acc=0.8724
# Epoch 39/50 | train_loss=0.3792 train_acc=0.8558 | val_loss=0.3391 val_acc=0.8803
# Epoch 40/50 | train_loss=0.3760 train_acc=0.8623 | val_loss=0.3425 val_acc=0.8773
# Epoch 41/50 | train_loss=0.3769 train_acc=0.8610 | val_loss=0.3419 val_acc=0.8843
# Epoch 42/50 | train_loss=0.3784 train_acc=0.8658 | val_loss=0.3305 val_acc=0.8922
# Epoch 43/50 | train_loss=0.3759 train_acc=0.8648 | val_loss=0.3537 val_acc=0.8704
# Epoch 44/50 | train_loss=0.3757 train_acc=0.8598 | val_loss=0.3446 val_acc=0.8853
# Epoch 45/50 | train_loss=0.3956 train_acc=0.8550 | val_loss=0.3322 val_acc=0.8813
# Epoch 46/50 | train_loss=0.3654 train_acc=0.8650 | val_loss=0.3389 val_acc=0.8853
# Epoch 47/50 | train_loss=0.3701 train_acc=0.8633 | val_loss=0.3271 val_acc=0.8912
# Epoch 48/50 | train_loss=0.3748 train_acc=0.8635 | val_loss=0.3392 val_acc=0.8833
# Epoch 49/50 | train_loss=0.3693 train_acc=0.8630 | val_loss=0.3493 val_acc=0.8714
# Epoch 50/50 | train_loss=0.3811 train_acc=0.8625 | val_loss=0.3380 val_acc=0.8754
# Training complete!
